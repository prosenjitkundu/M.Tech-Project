# %% [markdown]
# # LIBRARIES

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import scipy.io.wavfile as wav
from numpy.lib import stride_tricks
from scipy.signal import hilbert, find_peaks
import statistics

# %%
import math

# %%
# %matplotlib inline

# %% [markdown]
# # ACCESSING OF VOICE SIGNALS

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
import os
entries = os.listdir('D:/MTP-K.S RAO SIR/next step/VFD_all-20220710T040648Z-001/VFD_all/Cancer')

# %%
entries
# Out:
# ['.ipynb_checkpoints',
#  'F28U300915a1.wav',
#  'F28U300915a2.wav',
#  'F28U300915a3.wav',
#  'F28U300915a4.wav',
#  'F28U300915a5.wav',
#  'F28U300915a6.wav',
#  'F28U300915a7.wav',
#  'F28U300915a8.wav',
#  'F28U300915e1.wav',
#  'F28U300915e2.wav',
#  'F28U300915e3.wav',
#  'F28U300915e4.wav',
#  'F28U300915e5.wav',
#  'F28U300915e6.wav',
#  'F28U300915e7.wav',
#  'F28U300915e8.wav',
#  'F28U300915e9.wav',
#  'F28U300915o1.wav',
#  'F28U300915o2.wav',
#  'F28U300915o3.wav',
#  'F28U300915o4.wav',
#  'F28U300915o5.wav',
#  'F28U300915o6.wav',
#  'F28U300915o7.wav',
#  'F28U300915o8.wav',
#  'F28U300915o9.wav',
#  'F63U260717a1.wav',
#  'F63U260717a2.wav',
#  'F63U260717a3.wav',
#  'F63U260717a4.wav',
#  'F63U260717a5.wav',
#  'F63U260717e1.wav',
#  'F63U260717e2.wav',
#  'F63U260717e3.wav',
#  'F63U260717e4.wav',
#  'F63U260717o1.wav',
#  'F63U260717o2.wav',
#  'F63U260717o3.wav',
#  'F63U260717o4.wav',
#  'M52U180316a1.wav',
#  'M52U180316a2.wav',
#  'M52U180316a3.wav',
# ...

# %%
JR = []
CQ = []
SQ = []
PhasePeriod = []
vowels = []
voicecancer = [ 'F28U300915a1.wav',
 'F28U300915a2.wav',
 'F28U300915a3.wav',
 'F28U300915a4.wav',
 'F28U300915a5.wav',
 'F28U300915a6.wav',
 'F28U300915a7.wav',
 'F28U300915a8.wav',
 'F28U300915e1.wav',
 'F28U300915e2.wav',
 'F28U300915e3.wav',
 'F28U300915e4.wav',
 'F28U300915e5.wav',
 'F28U300915e6.wav',
 'F28U300915e7.wav',
 'F28U300915e8.wav',
 'F28U300915e9.wav',
 'F28U300915o1.wav',
 'F28U300915o2.wav',
 'F28U300915o3.wav',
 'F28U300915o4.wav',
 'F28U300915o5.wav',
 'F28U300915o6.wav',
 'F28U300915o7.wav',
 'F28U300915o8.wav',
 'F28U300915o9.wav',
 'F63U260717a1.wav',
 'F63U260717a2.wav',
 'F63U260717a3.wav',
 'F63U260717a4.wav',
 'F63U260717a5.wav',
 'F63U260717e1.wav',
 'F63U260717e2.wav',
 'F63U260717e3.wav',
 'F63U260717e4.wav',
 'F63U260717o1.wav',
 'F63U260717o2.wav',
 'F63U260717o3.wav',
 'F63U260717o4.wav',
 'M52U180316a1.wav',
 'M52U180316a2.wav',
 'M52U180316a3.wav',
 'M52U180316a4.wav',
 'M52U180316a5.wav',
 'M52U180316a6.wav',
 'M52U180316e1.wav',
 'M52U180316e2.wav',
 'M52U180316e3.wav',
 'M52U180316e4.wav',
 'M52U180316e5.wav',
 'M52U180316e6.wav',
 'M52U180316o1.wav',
 'M52U180316o2.wav',
 'M52U180316o4.wav',
 'M52U180316o5.wav',
 'M60U060116a1.wav',
 'M60U060116a2.wav',
 'M60U060116a3.wav',
 'M60U060116e1.wav',
 'M60U060116e2.wav',
 'M60U060116e3.wav',
 'M60U060116e4.wav',
 'M60U060116o1.wav',
 'M60U060116o2.wav',
 'M60U300915a1.wav',
 'M60U300915a2.wav',
 'M60U300915a3.wav',
 'M60U300915a4.wav',
 'M60U300915a5.wav',
 'M60U300915e1.wav',
 'M60U300915e2.wav',
 'M60U300915e4.wav',
 'M60U300915e5.wav',
 'M60U300915o1.wav',
 'M60U300915o2.wav',
 'M60U300915o3.wav',
 'M60U300915o4.wav',
 'M60U300915o5.wav',
 'M62U270416a1.wav',
 'M62U270416a2.wav',
 'M62U270416a3.wav',
 'M62U270416a4.wav',
 'M62U270416a5.wav',
 'M62U270416a6.wav',
 'M62U270416e1.wav',
 'M62U270416e2.wav',
 'M62U270416e3.wav',
 'M62U270416e4.wav',
 'M62U270416e5.wav',
 'M62U270416e6.wav',
 'M62U270416o1.wav',
 'M62U270416o2.wav',
 'M62U270416o4.wav',
 'M62U270416o5.wav',
 'M70U290716a1.wav',
 'M70U290716a2.wav',
 'M70U290716a3.wav',
 'M70U290716a4.wav',
 'M70U290716e1.wav',
 'M70U290716e2.wav',
 'M70U290716e3.wav',
 'M70U290716e4.wav',
 'M70U290716o1.wav',
 'M70U290716o2.wav',
 'M70U290716o3.wav',
 'M70U290716o4.wav',
 'M73U240917a1.wav',
 'M73U240917a2.wav',
 'M73U240917a3.wav',
 'M73U240917a4.wav',
 'M73U240917a5.wav',
 'M73U240917a6.wav',
 'M73U240917e1.wav',
 'M73U240917e2.wav',
 'M73U240917e3.wav',
 'M73U240917e4.wav',
 'M73U240917e5.wav',
 'M73U240917e6.wav',
 'M73U240917o1.wav',
 'M73U240917o2.wav',
 'M73U240917o3.wav',
 'M73U240917o4.wav',
 'M73U240917o5.wav']
for i in range(len(voicecancer)):
    try:
        v = voicecancer[i][len(voicecancer[i])-6]
        filename = voicecancer[i]
        samplerate, samples = wav.read(filename)
        samples = np.float_(samples)
        samples /= 32767
        data,sample_rate=librosa.load(filename)
        fd = 0.015
        f_size = math.floor(fd*sample_rate)
        n_f = math.floor(len(data)/f_size)
        egg = -1*samples[:,1]
        sound = samples[:,0]
        temp = 0
        frame = []
        print(voicecancer[i])
        #sm = 0
        for i in range(1,n_f):
            ftmp = []
            for j in range(temp+1,temp+f_size):
                ftmp.append(data[j])
                #sm += data[j]
            frame.append(ftmp)
            #sm = 0
            temp = temp + f_size
        n_silence = []
        f_egg = []
        f_sound = []
        idx = 1
        for i in range(len(frame)):
            if(statistics.variance(frame[i]) > 0.0005):
                idx +=1
                startf = i*f_size+1
                endf = startf+f_size
                endf = min(endf,len(egg))
                for j in range(startf,endf):
                    n_silence.append(data[j])
                    f_egg.append(egg[j])
                    f_sound.append(sound[j])
        final_egg = np.array(f_egg)
        found_sound = np.array(f_sound)
        final_egg = np.array(f_egg)
        diff_val = np.diff(final_egg)
        degg_ref = diff_val/max(abs(diff_val))
        analytic_signal = hilbert(final_egg)
        magnitude = np.abs(analytic_signal)
        phase = np.angle(analytic_signal)
        phase_unwrap = phase.copy()
        for pf in range(2,len(phase_unwrap)):
            difference = phase[pf] - phase[pf-1]
            if difference > np.pi:
                 for i in range(pf,len(phase_unwrap)):
                    phase_unwrap[pf]=phase_unwrap[pf]-2*np.pi
            elif difference < -np.pi:
                for i in range(pf,len(phase_unwrap)):
                    phase_unwrap[pf]=phase_unwrap[pf]+2*np.pi
        diff_ph = np.diff(phase_unwrap)
        sm_egg = np.average(diff_ph)
        peaks_gci, idx_gci = find_peaks(diff_ph, distance = 250)
        d_gci = np.zeros(len(final_egg))
        for i in range(len(peaks_gci)):
            d_gci[peaks_gci[i]] = 1
        mst = []
        fst = []
        lst = []
        for kk in range(len(peaks_gci)):
            mst.append(peaks_gci[kk])
            fst.append(mst[kk]-6)
            lst.append(mst[kk]+6)
            for p in range(fst[kk],lst[kk]):
                if p < len(diff_ph):
                    diff_ph[p] = 0.0
        peaks_goi, idx_goi = find_peaks(diff_ph, distance = 250)
        m = min(len(peaks_goi), len(peaks_gci))
        x = 0
        for i in range(m):
            PhasePeriod.append(abs(peaks_gci[x]-peaks_goi[i]))
        len(PhasePeriod)
        Tpavg = np.average(PhasePeriod)
        for i in range(min(m,len(PhasePeriod))-1):
            jr = np.abs(PhasePeriod[i]-PhasePeriod[i+1])
            jr /= Tpavg
            JR.append(jr)
        for i in range(min(m,len(PhasePeriod))):
            vowels.append(v)
            CQ.append(peaks_gci[i]/PhasePeriod[i])
        for i in range(min(m,len(PhasePeriod))):
            SQ.append(peaks_gci[i]/peaks_goi[i])
    except:
            pass
# Out:
# F28U300915a1.wav
# F28U300915a2.wav
# F28U300915a3.wav
# F28U300915a4.wav
# F28U300915a5.wav
# F28U300915a6.wav
# F28U300915a7.wav
# F28U300915a8.wav
# F28U300915e1.wav
# F28U300915e2.wav
# F28U300915e3.wav
# F28U300915e4.wav
# F28U300915e5.wav
# F28U300915e6.wav
# F28U300915e7.wav
# F28U300915e8.wav
# F28U300915e9.wav
# F28U300915o1.wav
# F28U300915o2.wav
# F28U300915o3.wav
# F28U300915o4.wav
# F28U300915o5.wav
# F28U300915o6.wav
# F28U300915o7.wav
# F28U300915o8.wav
# F28U300915o9.wav
# F63U260717a1.wav
# F63U260717a2.wav
# F63U260717a3.wav
# F63U260717a4.wav
# F63U260717a5.wav
# F63U260717e1.wav
# F63U260717e2.wav
# F63U260717e3.wav
# F63U260717e4.wav
# F63U260717o1.wav
# F63U260717o2.wav
# F63U260717o3.wav
# F63U260717o4.wav
# M52U180316a1.wav
# M52U180316a2.wav
# M52U180316a3.wav
# M52U180316a4.wav
# M52U180316a5.wav
# M52U180316a6.wav
# M52U180316e1.wav
# M52U180316e2.wav
# M52U180316e3.wav
# M52U180316e4.wav
# M52U180316e5.wav
# M52U180316e6.wav
# M52U180316o1.wav
# ...

# %%
len(CQ)
SQ.pop(-1)
CQ.pop(-1)
PhasePeriod.pop(-1)
vowels.pop(-1)
# Out:
# 'o'

# %%
f = min(len(JR), len(CQ), len(SQ), len(PhasePeriod), len(vowels))

# %%
f
# Out:
# 12120

# %%
import pandas as pd
df=pd.DataFrame(columns=['Jitter','CloseQuotient','SpeedQuotient','Phase','Target'])
df['Jitter']=JR[0:f]
df['CloseQuotient']=CQ[0:f]
df['SpeedQuotient']=SQ[0:f]
df['Phase']= PhasePeriod[0:f]
df['vowels'] = vowels[0:f]
df['Target']=['Cancer']*f

# %%
df.to_csv('Cancer.csv')
